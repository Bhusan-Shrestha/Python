# %%
# we are importing the necessary libraries
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
from matplotlib import pyplot as plt 
import seaborn as sns
import os

# %%
path=os.path.join('Data_Sets','used_cars.csv')
df0=pd.read_csv(path)
df0.head(1)
# Out:
#   brand                            model  model_year      milage  \
# 0  Ford  Utility Police Interceptor Base        2013  51,000 mi.
#
#        fuel_type                                                engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capability
#
#   transmission ext_col int_col                                accident  \
# 0  6-Speed A/T   Black   Black  At least 1 accident or damage reported
#
#   clean_title    price
# 0         Yes  $10,300

# %%
df=pd.read_csv(r'D:\Programming\python\Data_Analysis\Data_Sets\used_cars.csv')

# %%
df.head(2)
# Out:
#      brand                            model  model_year      milage  \
# 0     Ford  Utility Police Interceptor Base        2013  51,000 mi.
# 1  Hyundai                     Palisade SEL        2021  34,742 mi.
#
#        fuel_type                                                engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capability
# 1       Gasoline                                  3.8L V6 24V GDI DOHC
#
#         transmission          ext_col int_col  \
# 0        6-Speed A/T            Black   Black
# 1  8-Speed Automatic  Moonlight Cloud    Gray
#
#                                  accident clean_title    price
# 0  At least 1 accident or damage reported         Yes  $10,300
# 1  At least 1 accident or damage reported         Yes  $38,005

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4009 entries, 0 to 4008
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         4009 non-null   object
#  1   model         4009 non-null   object
#  2   model_year    4009 non-null   int64
#  3   milage        4009 non-null   object
#  4   fuel_type     3839 non-null   object
#  5   engine        4009 non-null   object
#  6   transmission  4009 non-null   object
#  7   ext_col       4009 non-null   object
#  8   int_col       4009 non-null   object
#  9   accident      3896 non-null   object
#  10  clean_title   3413 non-null   object
#  11  price         4009 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 376.0+ KB

# %%
df['milage']=df['milage'].str.replace('mi.','').str.replace(',','').astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4009 entries, 0 to 4008
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         4009 non-null   object
#  1   model         4009 non-null   object
#  2   model_year    4009 non-null   int64
#  3   milage        4009 non-null   float64
#  4   fuel_type     3839 non-null   object
#  5   engine        4009 non-null   object
#  6   transmission  4009 non-null   object
#  7   ext_col       4009 non-null   object
#  8   int_col       4009 non-null   object
#  9   accident      3896 non-null   object
#  10  clean_title   3413 non-null   object
#  11  price         4009 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 376.0+ KB

# %%
df.head()
# Out:
#       brand                            model  model_year   milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51000.0
# 1   Hyundai                     Palisade SEL        2021  34742.0
# 2     Lexus                    RX 350 RX 350        2022  22372.0
# 3  INFINITI                 Q50 Hybrid Sport        2015  88900.0
# 4      Audi        Q3 45 S line Premium Plus        2021   9835.0
#
#        fuel_type                                                engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capability
# 1       Gasoline                                  3.8L V6 24V GDI DOHC
# 2       Gasoline                                        3.5 Liter DOHC
# 3         Hybrid   354.0HP 3.5L V6 Cylinder Engine Gas/Electric Hybrid
# 4       Gasoline                            2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# ...

# %%
df.describe()
# Out:
#         model_year         milage
# count  4009.000000    4009.000000
# mean   2015.515590   64717.551010
# std       6.104816   52296.599459
# min    1974.000000     100.000000
# 25%    2012.000000   23044.000000
# 50%    2017.000000   52775.000000
# 75%    2020.000000   94100.000000
# max    2024.000000  405000.000000

# %%
df.sample(3)
# Out:
#               brand                   model  model_year    milage fuel_type  \
# 1030  Mercedes-Benz    G-Class G 550 4MATIC        2021   76100.0  Gasoline
# 2207        Pontiac            Solstice GXP        2009  122348.0  Gasoline
# 2839  Mercedes-Benz  G 550 4x4 Squared Base        2018   14381.0  Gasoline
#
#                                             engine       transmission  \
# 1030  416.0HP 4.0L 8 Cylinder Engine Gasoline Fuel                A/T
# 2207  260.0HP 2.0L 4 Cylinder Engine Gasoline Fuel                A/T
# 2839               4.0L V8 32V GDI DOHC Twin Turbo  7-Speed Automatic
#
#                   ext_col int_col                                accident  \
# 1030                Black   Black                           None reported
# 2207                  Red   Black  At least 1 accident or damage reported
# 2839  Designo Magno Matte   Black                           None reported
#
#      clean_title     price
# 1030         Yes  $130,000
# ...

# %%
df.shape
# Out:
# (4009, 12)

# %%
df['price']=df['price'].str.replace('$','').str.replace(',','').astype('float')

# %%
df.head(3)
# Out:
#      brand                            model  model_year   milage  \
# 0     Ford  Utility Police Interceptor Base        2013  51000.0
# 1  Hyundai                     Palisade SEL        2021  34742.0
# 2    Lexus                    RX 350 RX 350        2022  22372.0
#
#        fuel_type                                                engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capability
# 1       Gasoline                                  3.8L V6 24V GDI DOHC
# 2       Gasoline                                        3.5 Liter DOHC
#
#         transmission          ext_col int_col  \
# 0        6-Speed A/T            Black   Black
# 1  8-Speed Automatic  Moonlight Cloud    Gray
# 2          Automatic             Blue   Black
#
#                                  accident clean_title    price
# 0  At least 1 accident or damage reported         Yes  10300.0
# 1  At least 1 accident or damage reported         Yes  38005.0
# ...

# %%
pd.set_option('display.max_colwidth',None)
df['engine'].iloc[0:2]
# Out:
# 0    300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capability
# 1                                    3.8L V6 24V GDI DOHC
# Name: engine, dtype: object

# %%
df['Horsepower']=df['engine'].str.extract(r'(\d+\.\d+HP)|\d+HP')

# %%
df.head(4)
# Out:
#       brand                            model  model_year   milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51000.0
# 1   Hyundai                     Palisade SEL        2021  34742.0
# 2     Lexus                    RX 350 RX 350        2022  22372.0
# 3  INFINITI                 Q50 Hybrid Sport        2015  88900.0
#
#        fuel_type                                                engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capability
# 1       Gasoline                                  3.8L V6 24V GDI DOHC
# 2       Gasoline                                        3.5 Liter DOHC
# 3         Hybrid   354.0HP 3.5L V6 Cylinder Engine Gas/Electric Hybrid
#
#         transmission          ext_col int_col  \
# 0        6-Speed A/T            Black   Black
# 1  8-Speed Automatic  Moonlight Cloud    Gray
# 2          Automatic             Blue   Black
# 3        7-Speed A/T            Black   Black
#
# ...

# %%
df['Engine_Capacity']=df['engine'].str.extract(r'(\d+\.\d+L|\d+L|\d+\.\d+\s*Liter|\d+\s*Liter)')

# %%
df.head(5)
# Out:
#       brand                            model  model_year   milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51000.0
# 1   Hyundai                     Palisade SEL        2021  34742.0
# 2     Lexus                    RX 350 RX 350        2022  22372.0
# 3  INFINITI                 Q50 Hybrid Sport        2015  88900.0
# 4      Audi        Q3 45 S line Premium Plus        2021   9835.0
#
#        fuel_type                                                engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capability
# 1       Gasoline                                  3.8L V6 24V GDI DOHC
# 2       Gasoline                                        3.5 Liter DOHC
# 3         Hybrid   354.0HP 3.5L V6 Cylinder Engine Gas/Electric Hybrid
# 4       Gasoline                            2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# ...

# %%
df['accident_occured']=df['accident'].apply(lambda x: "NO" if x=="None reported" else "YES")

# %%
df.head()
# Out:
#       brand                            model  model_year   milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51000.0
# 1   Hyundai                     Palisade SEL        2021  34742.0
# 2     Lexus                    RX 350 RX 350        2022  22372.0
# 3  INFINITI                 Q50 Hybrid Sport        2015  88900.0
# 4      Audi        Q3 45 S line Premium Plus        2021   9835.0
#
#        fuel_type                                                engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capability
# 1       Gasoline                                  3.8L V6 24V GDI DOHC
# 2       Gasoline                                        3.5 Liter DOHC
# 3         Hybrid   354.0HP 3.5L V6 Cylinder Engine Gas/Electric Hybrid
# 4       Gasoline                            2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# ...

# %%
df['transmission']=df['transmission'].str.contains('Auto',case=False).map({True:"Automatic",False:"Manual"})

# %%
df.head()
# Out:
#       brand                            model  model_year   milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51000.0
# 1   Hyundai                     Palisade SEL        2021  34742.0
# 2     Lexus                    RX 350 RX 350        2022  22372.0
# 3  INFINITI                 Q50 Hybrid Sport        2015  88900.0
# 4      Audi        Q3 45 S line Premium Plus        2021   9835.0
#
#        fuel_type                                                engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capability
# 1       Gasoline                                  3.8L V6 24V GDI DOHC
# 2       Gasoline                                        3.5 Liter DOHC
# 3         Hybrid   354.0HP 3.5L V6 Cylinder Engine Gas/Electric Hybrid
# 4       Gasoline                            2.0L I4 16V GDI DOHC Turbo
#
#   transmission                 ext_col int_col  \
# 0       Manual                   Black   Black
# ...

# %%
df['Engine_Capacity']=df['Engine_Capacity'].str.replace('Liter','').str.replace('L','').astype('float')

# %%
df.head()
# Out:
#       brand                            model  model_year   milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51000.0
# 1   Hyundai                     Palisade SEL        2021  34742.0
# 2     Lexus                    RX 350 RX 350        2022  22372.0
# 3  INFINITI                 Q50 Hybrid Sport        2015  88900.0
# 4      Audi        Q3 45 S line Premium Plus        2021   9835.0
#
#        fuel_type                                                engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capability
# 1       Gasoline                                  3.8L V6 24V GDI DOHC
# 2       Gasoline                                        3.5 Liter DOHC
# 3         Hybrid   354.0HP 3.5L V6 Cylinder Engine Gas/Electric Hybrid
# 4       Gasoline                            2.0L I4 16V GDI DOHC Turbo
#
#   transmission                 ext_col int_col  \
# 0       Manual                   Black   Black
# ...

# %%
df['Horsepower']=df['Horsepower'].str.replace('HP','').astype('float')

# %%
df.head()
# Out:
#       brand                            model  model_year   milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51000.0
# 1   Hyundai                     Palisade SEL        2021  34742.0
# 2     Lexus                    RX 350 RX 350        2022  22372.0
# 3  INFINITI                 Q50 Hybrid Sport        2015  88900.0
# 4      Audi        Q3 45 S line Premium Plus        2021   9835.0
#
#        fuel_type                                                engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capability
# 1       Gasoline                                  3.8L V6 24V GDI DOHC
# 2       Gasoline                                        3.5 Liter DOHC
# 3         Hybrid   354.0HP 3.5L V6 Cylinder Engine Gas/Electric Hybrid
# 4       Gasoline                            2.0L I4 16V GDI DOHC Turbo
#
#   transmission                 ext_col int_col  \
# 0       Manual                   Black   Black
# ...

# %%
df.rename(columns={'ext_col':'External_column'},inplace=True)

# %%
df.head()
# Out:
#       brand                            model  model_year   milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51000.0
# 1   Hyundai                     Palisade SEL        2021  34742.0
# 2     Lexus                    RX 350 RX 350        2022  22372.0
# 3  INFINITI                 Q50 Hybrid Sport        2015  88900.0
# 4      Audi        Q3 45 S line Premium Plus        2021   9835.0
#
#        fuel_type                                                engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capability
# 1       Gasoline                                  3.8L V6 24V GDI DOHC
# 2       Gasoline                                        3.5 Liter DOHC
# 3         Hybrid   354.0HP 3.5L V6 Cylinder Engine Gas/Electric Hybrid
# 4       Gasoline                            2.0L I4 16V GDI DOHC Turbo
#
#   transmission         External_column int_col  \
# 0       Manual                   Black   Black
# ...

# %%
df.rename(columns={'int_col':'Internal_column'},inplace=True)

# %%
df.head()
# Out:
#       brand                            model  model_year   milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51000.0
# 1   Hyundai                     Palisade SEL        2021  34742.0
# 2     Lexus                    RX 350 RX 350        2022  22372.0
# 3  INFINITI                 Q50 Hybrid Sport        2015  88900.0
# 4      Audi        Q3 45 S line Premium Plus        2021   9835.0
#
#        fuel_type                                                engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capability
# 1       Gasoline                                  3.8L V6 24V GDI DOHC
# 2       Gasoline                                        3.5 Liter DOHC
# 3         Hybrid   354.0HP 3.5L V6 Cylinder Engine Gas/Electric Hybrid
# 4       Gasoline                            2.0L I4 16V GDI DOHC Turbo
#
#   transmission         External_column Internal_column  \
# 0       Manual                   Black           Black
# ...

# %%
useless=['engine','accident']
df.drop(columns=useless,axis=1,inplace=True)

# %%
df.head()
# Out:
#       brand                            model  model_year   milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51000.0
# 1   Hyundai                     Palisade SEL        2021  34742.0
# 2     Lexus                    RX 350 RX 350        2022  22372.0
# 3  INFINITI                 Q50 Hybrid Sport        2015  88900.0
# 4      Audi        Q3 45 S line Premium Plus        2021   9835.0
#
#        fuel_type transmission         External_column Internal_column  \
# 0  E85 Flex Fuel       Manual                   Black           Black
# 1       Gasoline    Automatic         Moonlight Cloud            Gray
# 2       Gasoline    Automatic                    Blue           Black
# 3         Hybrid       Manual                   Black           Black
# 4       Gasoline    Automatic  Glacier White Metallic           Black
#
#   clean_title    price  Horsepower  Engine_Capacity accident_occured
# 0         Yes  10300.0       300.0              3.7              YES
# ...

# %%
df.isnull().sum()
# Out:
# brand                 0
# model                 0
# model_year            0
# milage                0
# fuel_type           170
# transmission          0
# External_column       0
# Internal_column       0
# clean_title         596
# price                 0
# Horsepower          810
# Engine_Capacity     219
# accident_occured      0
# dtype: int64

# %%
missing_info={}
for col in df.columns:
    if df[col].isnull().sum()>0:
        missing_count=(df[col].isnull().sum()/len(df))*100
        missing_info[col]=round(missing_count,2)

print('The colums with missing percentage are:')
for col,perc in missing_info.items():
    print(f'{col}: {perc}%')
# Out:
# The colums with missing percentage are:
# fuel_type: 4.24%
# clean_title: 14.87%
# Horsepower: 20.2%
# Engine_Capacity: 5.46%

# %%
numerical_columns=df.select_dtypes(include=['number','int64','int32','float64','float32']).columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4009 entries, 0 to 4008
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   brand             4009 non-null   object
#  1   model             4009 non-null   object
#  2   model_year        4009 non-null   int64
#  3   milage            4009 non-null   float64
#  4   fuel_type         3839 non-null   object
#  5   transmission      4009 non-null   object
#  6   External_column   4009 non-null   object
#  7   Internal_column   4009 non-null   object
#  8   clean_title       3413 non-null   object
#  9   price             4009 non-null   float64
#  10  Horsepower        3199 non-null   float64
#  11  Engine_Capacity   3790 non-null   float64
#  12  accident_occured  4009 non-null   object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 407.3+ KB

# %%
df[numerical_columns].head()
# Out:
#    model_year   milage    price  Horsepower  Engine_Capacity
# 0        2013  51000.0  10300.0       300.0              3.7
# 1        2021  34742.0  38005.0         NaN              3.8
# 2        2022  22372.0  54598.0         NaN              3.5
# 3        2015  88900.0  15500.0       354.0              3.5
# 4        2021   9835.0  34999.0         NaN              2.0
